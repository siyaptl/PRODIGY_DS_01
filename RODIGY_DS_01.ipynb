# %%
import pandas as pd
import zipfile
import os

# Define the correct path to the ZIP file after uploading
zip_file_path = 'API_SP.POP.TOTL_DS2_en_csv_v2_372468.zip'  # Use the correct path to the uploaded file

# Extract the CSV file from the ZIP archive
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # List all files in the ZIP archive
    print("Files in the ZIP archive:", zip_ref.namelist())

    # Extract the specific CSV file you need
    csv_file_name = 'API_SP.POP.TOTL_DS2_en_csv_v2_372468.csv'  # Update this to the file you need
    zip_ref.extract(csv_file_name, 'extracted_files')

# Define the path to the extracted CSV file
csv_file_path = os.path.join('extracted_files', csv_file_name)
# Out:
# Files in the ZIP archive: ['Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_372468.csv', 'API_SP.POP.TOTL_DS2_en_csv_v2_372468.csv', 'Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_372468.csv']

# %%
try:
    # Read the extracted CSV file into a DataFrame
    data = pd.read_csv(csv_file_path, skiprows=4)  # Skip the first four rows which are metadata

    # Set pandas to display all columns
    pd.set_option('display.max_columns', None)

    # Display the first few rows of the DataFrame
    display(data.head())
except FileNotFoundError:
    print("The file was not found. Please check the file path and try again.")
except pd.errors.ParserError as e:
    print("Error parsing the file:", e)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965         1966         1967         1968         1969  \
# ...

# %%
# Display the last few rows of the DataFrame to ensure data is loaded correctly
display(data.tail())
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965        1966  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0   1106000.0
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0   6228430.0
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  19789771.0
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0   3777680.0
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0   4588529.0
#
# ...

# %%
# Display the shape of the DataFrame
print("Shape of the DataFrame:", data.shape)
# Out:
# Shape of the DataFrame: (266, 69)

# %%
# Display the columns of the DataFrame
print("Columns in the DataFrame:")
print(data.columns)
# Out:
# Columns in the DataFrame:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
# Display the types of the DataFrame columns
print("Types of the DataFrame columns:")
print(data.dtypes)
# Out:
# Types of the DataFrame columns:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# Unnamed: 68       float64
# Length: 69, dtype: object

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
# Display summary statistics of the DataFrame
print("Summary statistics of the DataFrame:")
print(data.describe())
# Out:
# Summary statistics of the DataFrame:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.695500e+08  3.740958e+08  3.808121e+08  3.895098e+08  3.982497e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# ...

# %%
duplicate_sum = data.duplicated().sum()
print(f"Sum of duplicate rows: {duplicate_sum}")
# Out:
# Sum of duplicate rows: 0

# %%
are_there_missing_values = data.isna().sum().any()
print(f"Are there any missing values in the DataFrame? {are_there_missing_values}")
# Out:
# Are there any missing values in the DataFrame? True

# %%
data.fillna(method='ffill', inplace=True)

# Display the updated DataFrame after filling missing values
print("Updated DataFrame after filling missing values:")
display(data.head())
# Out:
# Updated DataFrame after filling missing values:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
# ...

# %%
print(data.isna().sum().any())
# Out:
# True

# %%
# Get unique values in the "Country Name" column
unique_countries = data['Country Name'].unique()
print("Unique Country Names:")
print(unique_countries)
# Out:
# Unique Country Names:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
# Get unique values in the "Country Code" column
unique_country_codes = data['Country Code'].unique()
print("Unique Country Codes:")
print(unique_country_codes)
# Out:
# Unique Country Codes:
# ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'INX' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN'
#  'KAZ' 'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR'
#  'LBY' 'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU'
#  'LUX' 'LVA' 'MAC' 'MAF' 'MAR' 'MCO' 'MDA' 'MDG' 'MDV' 'MEA' 'MEX' 'MHL'
# ...

# %%
# Get unique values in the "Indicator Name" column
unique_indicator_names = data['Indicator Name'].unique()
print("Unique Indicator Names:")
print(unique_indicator_names)
# Out:
# Unique Indicator Names:
# ['Population, total']

# %%
# Get unique values in the "Indicator Code" column
unique_indicator_codes = data['Indicator Code'].unique()
print("Unique Indicator Codes:")
print(unique_indicator_codes)
# Out:
# Unique Indicator Codes:
# ['SP.POP.TOTL']

# %%
# Drop columns "Indicator Name", "Indicator Code", and "Country Code" from the DataFrame
data.drop(['Indicator Name', 'Indicator Code', 'Country Code'], axis=1, inplace=True)

# Display the updated DataFrame
print("Updated DataFrame after dropping columns:")
print(data.head())
# Out:
# Updated DataFrame after dropping columns:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968         1969         1970         1971         1972  \
# ...

# %%
# Display the columns of the DataFrame
print("Columns in the DataFrame after dropping 'Indicator Name', 'Indicator Code', and 'Country Code':")
print(data.columns)
# Out:
# Columns in the DataFrame after dropping 'Indicator Name', 'Indicator Code', and 'Country Code':
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data' is your DataFrame
data = pd.DataFrame({
    'Country Name': ['USA', 'China', 'India', 'Russia', 'Japan', 'Germany', 'Brazil', 'UK', 'France', 'Italy'],
    '1960': [180671000, 667070000, 449480608, 119897000, 92500572, 72814900, 72493585, 52400000, 46814237, 50199700],
    '1970': [205052000, 818315000, 553574098, 130396000, 107188116, 78312842, 95015573, 56000000, 52041686, 54365564],
    '1980': [227225000, 981235000, 683329097, 141394000, 117048000, 78197563, 119002706, 56300000, 54607247, 56079100],
    '1990': [249623000, 1135185000, 838251046, 148244000, 123611167, 79668900, 146917459, 57800000, 56846821, 56983200],
    '2000': [282162411, 1262645000, 1006302000, 145470000, 126843000, 82266372, 172006362, 58892514, 59147000, 57680000],
    '2010': [309321666, 1337705000, 1234281170, 142857000, 127445000, 81802257, 190732694, 62026962, 64395345, 60795612],
    '2020': [331002651, 1444216107, 1366417754, 145912025, 125410000, 83783942, 212559417, 67886011, 65273511, 60244639],
})

# Set the index to 'Country Name'
data.set_index('Country Name', inplace=True)

# Selecting years from 1960 to 2020
years = data.columns

# Plotting the data for each year
for year in years:
    plt.figure(figsize=(10, 5))
    plt.hist(data[year], color='blue', bins=20)
    plt.xlabel('Population')
    plt.ylabel('Frequency')
    plt.title(f'Distribution of Population in {year}')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data' is your DataFrame
data = pd.DataFrame({
    'Country Name': ['USA', 'China', 'India', 'Russia', 'Japan', 'Germany', 'Brazil', 'UK', 'France', 'Italy'],
    '1960': [180671000, 667070000, 449480608, 119897000, 92500572, 72814900, 72493585, 52400000, 46814237, 50199700],
    '1970': [205052000, 818315000, 553574098, 130396000, 107188116, 78312842, 95015573, 56000000, 52041686, 54365564],
    '1980': [227225000, 981235000, 683329097, 141394000, 117048000, 78197563, 119002706, 56300000, 54607247, 56079100],
    '1990': [249623000, 1135185000, 838251046, 148244000, 123611167, 79668900, 146917459, 57800000, 56846821, 56983200],
    '2000': [282162411, 1262645000, 1006302000, 145470000, 126843000, 82266372, 172006362, 58892514, 59147000, 57680000],
    '2010': [309321666, 1337705000, 1234281170, 142857000, 127445000, 81802257, 190732694, 62026962, 64395345, 60795612],
    '2020': [331002651, 1444216107, 1366417754, 145912025, 125410000, 83783942, 212559417, 67886011, 65273511, 60244639],
})

# Set the index to 'Country Name'
data.set_index('Country Name', inplace=True)

# Selecting years from 1960 to 2020
years = data.columns

# Plotting the data for each year
plt.figure(figsize=(12, 8))

for idx, year in enumerate(years):
    plt.bar([x + idx * 0.1 for x in range(len(data.index))], data[year], width=0.1, label=year)

# Adding labels and title
plt.xlabel('Countries')
plt.ylabel('Population')
plt.title('Population by Country (1960-2020)')
plt.xticks(range(len(data.index)), data.index, rotation=90)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# Plotting a histogram for a specific year (e.g., 1960)
plt.figure()
plt.hist(data['1960'], color='blue', bins=20)  # Adjust 'color' and 'bins' as needed
plt.xlabel('Population in 1960')
plt.ylabel('Frequency')
plt.title('Histogram of Population in 1960')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already loaded the DataFrame 'data'
# Select years columns
years = data.columns[4:-1]

# Calculate total values across years for each column
total_values = data[years].sum()

# Create a new figure
plt.figure(figsize=(10, 10))

# Plot the horizontal bar chart
plt.barh(total_values.index, total_values.values, color='green')

# Set labels and title
plt.xlabel('Total Values')
plt.ylabel('Years')
plt.title('Total Values Across Years for Each Column')

# Show plot
plt.tight_layout()
plt.show()

# %%
top_countries_1960 = data[['Country Name', '1960']].sort_values(by='1960', ascending=False).head()

print(top_countries_1960)
# Out:
#             Country Name          1960
# 259                World  3.031474e+09
# 103     IDA & IBRD total  2.297972e+09
# 140  Low & middle income  2.243179e+09
# 156        Middle income  2.107416e+09
# 102            IBRD only  1.904347e+09

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data' is your DataFrame
data = pd.DataFrame({
    'Country Name': ['USA', 'China', 'India', 'Russia', 'Japan', 'Germany', 'Brazil', 'UK', 'France', 'Italy'],
    '1960': [180671000, 667070000, 449480608, 119897000, 92500572, 72814900, 72493585, 52400000, 46814237, 50199700],
    '1970': [205052000, 818315000, 553574098, 130396000, 107188116, 78312842, 95015573, 56000000, 52041686, 54365564],
    '1980': [227225000, 981235000, 683329097, 141394000, 117048000, 78197563, 119002706, 56300000, 54607247, 56079100],
    '1990': [249623000, 1135185000, 838251046, 148244000, 123611167, 79668900, 146917459, 57800000, 56846821, 56983200],
    '2000': [282162411, 1262645000, 1006302000, 145470000, 126843000, 82266372, 172006362, 58892514, 59147000, 57680000],
    '2010': [309321666, 1337705000, 1234281170, 142857000, 127445000, 81802257, 190732694, 62026962, 64395345, 60795612],
    '2020': [331002651, 1444216107, 1366417754, 145912025, 125410000, 83783942, 212559417, 67886011, 65273511, 60244639],
})

# Set the index to 'Country Name'
data.set_index('Country Name', inplace=True)

# Selecting years from 1960 to 2020
years = data.columns

# Plotting each year individually
plt.figure(figsize=(12, 8))

for idx, year in enumerate(years):
    plt.subplot(4, 3, idx + 1)
    plt.bar(data.index, data[year], width=0.4, label=year)
    plt.xlabel('Countries')
    plt.ylabel('Population')
    plt.title(f'Population in {year}')
    plt.xticks(rotation=90)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Sort countries by population in 2022 and select top 00
data_2020_top10 = data['2020'].sort_values(ascending=False).head(10)

# Create a DataFrame for better tabular display
top20_df = pd.DataFrame(data_2020_top10)
top20_df.reset_index(inplace=True)
top20_df.columns = ['Country Name', 'Population in 2022']

# Display the top 10 countries in a tabular form
print(top20_df)
# Out:
#   Country Name  Population in 2022
# 0        China          1444216107
# 1        India          1366417754
# 2          USA           331002651
# 3       Brazil           212559417
# 4       Russia           145912025
# 5        Japan           125410000
# 6      Germany            83783942
# 7           UK            67886011
# 8       France            65273511
# 9        Italy            60244639

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data' is your DataFrame
data = pd.DataFrame({
    'Country Name': ['USA', 'China', 'India', 'Russia', 'Japan', 'Germany', 'Brazil', 'UK', 'France', 'Italy'],
    '1960': [180671000, 667070000, 449480608, 119897000, 92500572, 72814900, 72493585, 52400000, 46814237, 50199700],
    '1970': [205052000, 818315000, 553574098, 130396000, 107188116, 78312842, 95015573, 56000000, 52041686, 54365564],
    '1980': [227225000, 981235000, 683329097, 141394000, 117048000, 78197563, 119002706, 56300000, 54607247, 56079100],
    '1990': [249623000, 1135185000, 838251046, 148244000, 123611167, 79668900, 146917459, 57800000, 56846821, 56983200],
    '2000': [282162411, 1262645000, 1006302000, 145470000, 126843000, 82266372, 172006362, 58892514, 59147000, 57680000],
    '2010': [309321666, 1337705000, 1234281170, 142857000, 127445000, 81802257, 190732694, 62026962, 64395345, 60795612],
    '2020': [331002651, 1444216107, 1366417754, 145912025, 125410000, 83783942, 212559417, 67886011, 65273511, 60244639],
})

# Set the index to 'Country Name'
data.set_index('Country Name', inplace=True)

# Selecting years from 1960 to 2020
years = data.columns

# Plotting separate graphs for each year
for year in years:
    plt.figure(figsize=(10, 6))
    plt.bar(data.index, data[year], color='blue')
    plt.xlabel('Countries')
    plt.ylabel('Population')
    plt.title(f'Population by Country in {year}')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
